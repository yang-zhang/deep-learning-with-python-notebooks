# %%
import keras
keras.__version__
# Out:
# Using TensorFlow backend.
# '2.1.2'

# %% [markdown]
# # Text generation with LSTM
#
# This notebook contains the code samples found in Chapter 8, Section 1 of [Deep Learning with Python](https://www.manning.com/books/deep-learning-with-python?a_aid=keras&a_bid=76564dff). Note that the original text features far more content, in particular further explanations and figures: in this notebook, you will only find source code and related comments.
#
# ----
#
# [...]
#
# ## Implementing character-level LSTM text generation
#
#
# Let's put these ideas in practice in a Keras implementation. The first thing we need is a lot of text data that we can use to learn a
# language model. You could use any sufficiently large text file or set of text files -- Wikipedia, the Lord of the Rings, etc. In this
# example we will use some of the writings of Nietzsche, the late-19th century German philosopher (translated to English). The language model
# we will learn will thus be specifically a model of Nietzsche's writing style and topics of choice, rather than a more generic model of the
# English language.

# %% [markdown]
# ## Preparing the data
#
# Let's start by downloading the corpus and converting it to lowercase:

# %%
import keras
import numpy as np
import io

path = keras.utils.get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = io.open(path, encoding='utf-8').read().lower()
print('Corpus length:', len(text))
# Out:
# Corpus length: 600893

# %% [markdown]
# Next, we will extract partially-overlapping sequences of length `maxlen`, one-hot encode them and pack them in a 3D Numpy array `x` of
# shape `(sequences, maxlen, unique_characters)`. Simultaneously, we prepare a array `y` containing the corresponding targets: the one-hot
# encoded characters that come right after each extracted sequence.

# %%
# Length of extracted character sequences
maxlen = 60

# We sample a new sequence every `step` characters
step = 3

# This holds our extracted sequences
sentences = []

# This holds the targets (the follow-up characters)
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('Number of sequences:', len(sentences))

# List of unique characters in the corpus
chars = sorted(list(set(text)))
print('Unique characters:', len(chars))
# Dictionary mapping unique characters to their index in `chars`
char_indices = dict((char, chars.index(char)) for char in chars)

# Next, one-hot encode the characters into binary arrays.
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 200278
# Unique characters: 57
# Vectorization...

# %% [markdown]
# ## Building the network
#
# Our network is a single `LSTM` layer followed by a `Dense` classifier and softmax over all possible characters. But let us note that
# recurrent neural networks are not the only way to do sequence data generation; 1D convnets also have proven extremely successful at it in
# recent times.

# %%
from keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:1247: calling reduce_sum (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %% [markdown]
# Since our targets are one-hot encoded, we will use `categorical_crossentropy` as the loss to train the model:

# %%
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py:1349: calling reduce_mean (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %% [markdown]
# ## Training the language model and sampling from it
#
#
# Given a trained model and a seed text snippet, we generate new text by repeatedly:
#
# * 1) Drawing from the model a probability distribution over the next character given the text available so far
# * 2) Reweighting the distribution to a certain "temperature"
# * 3) Sampling the next character at random according to the reweighted distribution
# * 4) Adding the new character at the end of the available text
#
# This is the code we use to reweight the original probability distribution coming out of the model,
# and draw a character index from it (the "sampling function"):

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %% [markdown]
# Finally, this is the loop where we repeatedly train and generated text. We start generating text using a range of different temperatures
# after every epoch. This allows us to see how the generated text evolves as the model starts converging, as well as the impact of
# temperature in the sampling strategy.

# %%
import random
import sys

for epoch in range(1, 60):
    print('epoch', epoch)
    # Fit the model for 1 epoch on the available training data
    model.fit(x, y,
              batch_size=128,
              epochs=1)

    # Select a text seed at random
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated_text = text[start_index: start_index + maxlen]
    print('--- Generating with seed: "' + generated_text + '"')

    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ temperature:', temperature)
        sys.stdout.write(generated_text)

        # We generate 400 characters
        for i in range(400):
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.

            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]

            generated_text += next_char
            generated_text = generated_text[1:]

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# epoch 1
# Epoch 1/1
# 200278/200278 [==============================] - 140s 701us/step - loss: 1.9454
# --- Generating with seed: " very
# grateful, very patient, very complaisant--but with all"
# ------ temperature: 0.2
#  very
# grateful, very patient, very complaisant--but with all the greating of the self and the are the struch and the self the fand of the most and the derious one a man to be the sensical and the intimed to the sensiness of the postion of the beansity of the spincing of a self the concentions of the man the self the greating of the sensing of the good of the sensing and fore the most of the present of the concentions of the self and souls of the sense the
# ------ temperature: 0.5
# t of the concentions of the self and souls of the sense the finds the spirntnt of his istence and something in the condine and noter to the geners of the spection of a predection of the sundires even to concerding of explanical like the dors and perhingly been that which be thing of the conside to intinetion of the inting and strutdest and the self the strutges to himsestional to the presentions, and perhing of the hard concentions of pains of a man and on
# ------ temperature: 1.0
# and perhing of the hard concentions of pains of a man and one to pains expripreucations of ochtwence for in in the . was the possible forent.--wages which his e to
# the
# mendine tive. it toly oder to when the felured has tewign all explishing corfationshy fay pootent sli-inal pe benrieal atrouble
# convented buevely and our dladoon fries ourugh ali grigh pessions but in upeppiching goonity "explencaines aboruewly digner child of with even mo our pease fecome o
# ------ temperature: 1.2
# es aboruewly digner child of with even mo our pease fecome of souls
# allepation of a so
# trusti7nly in the
# chomant, "masr percations? he we projobition" of
# scuerthed (nammed frienting" of "one fainhrive
# feltws our allood: the
#
# b; the montlyy weactun-thements--angied, it inof
# the padans. out it tain there, that excirerphetations, and ansiendment wele as viir diffichles
# windwnergly, pain sha mitntos of su;sipidion, one rished, henreoble
# bran. the adi awroirmit
# epoch 2
# Epoch 1/1
# 200278/200278 [==============================] - 139s 696us/step - loss: 1.6142
# --- Generating with seed: "ander: one over another.
#
#
# 8
#
# to what stage in the developme"
# ------ temperature: 0.2
# ander: one over another.
#
#
# 8
#
# to what stage in the development to the contrious the something and the presence of the something the something in the present the something the problem and the artist to the content and the presence of the condition of the presence of the something the sense of the contrious the something the self-and and the concertion of the contrious the foredoman for the soulsed and the problem of the more artion of the sense of the doral
# ------ temperature: 0.5
# and the problem of the more artion of the sense of the doralmatically and precised superficual and domear of sones of the subliment and more good and complement, and man of the sense he artist that the soul, and some to the continue one the baring decised that it is pressing of an anciest the entide all some the readile that and discontimety and the contemnerial and one may bad to perplibe be a do alteded and the something percatis, and even and the englit
# ------ temperature: 1.0
#  alteded and the something percatis, and even and the englith for the incrared somass to fach downed be                    gon" who bey cause "fathely."--for being pl faotisys all artinance, us it as he doublays tremiblenen for e,
# itkinds intere what is and doend in is, the cast to hitherto maxics rikes as procosomuto, withingver good.. the mey this be, that "fattererly as of el, him a undorranceiblen,
# dimied in this
# mad, and explopted, perhaps our flarour
# ------ temperature: 1.2
# blen,
# dimied in this
# mad, and explopted, perhaps our flarour, aiture momener concomple mude", suchorficie of departilienes, distime!iur. good
# a mean, it, ave others, that vertationalizity ratain nomer he muse opinian eristerised ap-etysman personims
# loined, as and is, of human cotuinatesely lend-for interplacedners, and lofte
# on e: agmanable ploame-that i to operate sible e to themgs
#
# than is parhong-concestions to this sids, brivmunear-"man"" how weans, i
# epoch 3
# Epoch 1/1
# 200278/200278 [==============================] - 139s 696us/step - loss: 1.5316
# --- Generating with seed: "i belong?--but not to
# myself, as is sufficiently agreeable t"
# ------ temperature: 0.2
# i belong?--but not to
# myself, as is sufficiently agreeable to the self--and the secretion of the discomparish the strong and the strong the subtle of the senses the sense the strong and the superiority and the self--and to the sense the secretion of the self-god the superition of the strong and the strong and in the sentiments. the self-god to the secreting the strong and is the school, and the self to the superiority of the self--and and destrust the same
# ------ temperature: 0.5
# lf to the superiority of the self--and and destrust the same the conscious that is every one of the say for the seciety for the decect the spiritual the speciness of the highest and its made belongs to the thing love wrough and for the spirit of the sense the should not the severent than he last be deterious could and his feard for the possible the called philosophy are of a thing the dream, so the success, and the man
# the most betreans and means the my ha
# ------ temperature: 1.0
# e success, and the man
# the most betreans and means the my have bestowed stronger fithelwer ascocres--from the estrainese--the in the philosophy
# to his, it is good
# vene dulination are ecritiours of geners. herefore ign of welived, sayncatenre salvating, and feave it reew too, the valued but which is the sun degands its brow, soough we
# agk of sysperi, agains
# from stringly, long-nothes allool cade the gool and weak questipn
# and
# seekers would it and to out an
# ------ temperature: 1.2
# e gool and weak questipn
# and
# seekers would it and to out an he time--wlects--usportantly
# dreams of no momen seom conflust educatent by the enough as contradings: he aboutbydity--thems.
#
# he regard of the -shound evered taste as spirit the
# mos--"elfumance and the degand a
# meathy. hough to gepes aither, unbetta. , the scenetafrally copsciofw--and nesates. a powerar probly that as astenies ourc? but no othay actery of the dors with timouses.
#
# vaniubs.--
# clea
# epoch 4
# Epoch 1/1
# 200278/200278 [==============================] - 139s 696us/step - loss: 1.4897
# --- Generating with seed: " science must pay more attention than to the
# great, uncommon"
# ------ temperature: 0.2
#  science must pay more attention than to the
# great, uncommon the sense to the sense to the sense to the man to the sense of the sense to the sense to the world to the sense of the sense to the sense to the sense to the sense to the sense to the has to the are to the sense to the sense of the sense to the artisted and sense to the fact to the sense to the conscience of the sense to the sense to the sense to the hard to the sense to the sense the sense the s
# ------ temperature: 0.5
#  sense to the hard to the sense to the sense the sense the self in distruction and subtle to an an
# except and long the sense to be german of the way of man to the
# sense and to the tange which is the relations to the same superioring to an except and man and demand to never the world of our europe to a for the
# power, the sense to distance for the very pates and suspect to the world and all sonly be and lows and the masters to yet now the advance and lead to
# ------ temperature: 1.0
#  and lows and the masters to yet now the advance and lead to
# let a new speaknieg--made be
# sense, the parized, he losiculy to quesi
# france to ailticely "bility sampity and utis woman, is not menion lacely thoued one demands what is fuldlly light there for they areid what as when one of the as tome canverse of the
# from eveny in
# li rored--as a dreager against their pices become for a memaple
# conduct you gods, in whoever goods experts end to for they selked of
# ------ temperature: 1.2
# you gods, in whoever goods experts end to for they selked of "good asd on eye of yet very
# differing pechuponered gittiesly ! to inaducular german mpsycis exgight guiral clunder temand conwers ring and "perhaps e stoll -for dve good. "edless do, schrowe norse have of indredg; but!--he bentard, -to be badce cannow, hy lasherubling, huppalby be
# when tilling with
# divligional of god-comed  compulse whanugh, leads door
# ; we
# marrimones
# and
# ryquentable heal thy "g
# epoch 5
# Epoch 1/1
# 200278/200278 [==============================] - 139s 696us/step - loss: 1.4621
# --- Generating with seed: "ey themselves say and believe--the jews performed the miracl"
# ------ temperature: 0.2
# ey themselves say and believe--the jews performed the miracle of the subjection of the self as a souls of a philosophers all the subject of the self-similation of the subject and all the subject in the subject of the self-sonish of the self-superation, and the subjection of the strange the subjection of the world of the spirits of the self-sinile the subject of the sentiment and the sublime the subjection of the self-such a sublime and the sublimates of th
# ------ temperature: 0.5
# bjection of the self-such a sublime and the sublimates of the disting
# and manifect and sort of indiveduation that is in the simplent and little the solitude man in the good and orders and it will the sublimest and manners, and or from the taste the superation, in the decided souls. as the similar
# point of the states, a philosophers and morality and believe the possible to state of the spirit of philosophers whether how wishes of the self interposed because
# ------ temperature: 1.0
# ilosophers whether how wishes of the self interposed because to good more, which as pro. was hepre"ss and lin for his couds. therefor, autubling
# of the
# crealvaring, or philosophers
# can takeva in a peyceive, into letserratives
# type of their advanalily of shame is the
# cise broogse from ourselves, as refled that withtored a felicd dote. which, it is and been twith trubute and believe benelf its not course according within orldest, as a god for imagine is a co
# ------ temperature: 1.2
# ourse according within orldest, as a god for imagine is a could be intexarato towards love-putived there-di easily importen "hals, and quite it go, are yesions matfifach toigh
# of had onfual our pravastatior and the allato,.
#
#
# 14
#
# =perhads
# forhiegines,
# hene ofecre
# nocksd
# igens"
# wigh its this all inimaw, "verind, to segrtoradingy. heaved
# berong pre: wisone of belief does a good mentational beridilities, rele benevolicalicisive fifl erety of falutivelth tesss
# epoch 6
# Epoch 1/1
# 200278/200278 [==============================] - 139s 696us/step - loss: 1.4405
# --- Generating with seed: "ors and
# panegyrists, the apostles of "modern ideas," would l"
# ------ temperature: 0.2
# ors and
# panegyrists, the apostles of "modern ideas," would learn and so the strength the most present the strength the present the senses of the senses to the same self-concernity of the complised and consequently and so the same the same the strong and the completely the complate and intellectual and the some strength and so the senses to the present the consequently and suffering the strength and the consequently and in the southers, and the concernity t
# ------ temperature: 0.5
# d the consequently and in the southers, and the concernity to the adopenal concernity, the procoses to the commanding and always of the most farther in the preservation of the own the called very at the precisely the come the presence of hearthing and the strength and "wishent of the life the christianity of a hugoious intention of the supercitions of a christian in the consequence of itself to the possessions of the transful, the thing the development and
# ------ temperature: 1.0
# e possessions of the transful, the thing the development and    religions is the carnedy such velse self-t tive the pressing-unfatieure: as testained and sensuable
# happene, is preswor does not
# with sritived: anwishion of
# the solitude, whereefore
# of a sthut
# much you
# seems. it is heaverdul and in surslokent
# of reproped houses, how
# characteronism to
# of every roment as as has he last! finds from respecters as is, which
# the impersible to
# is heirs.--we free-pred
# ------ temperature: 1.2
# cters as is, which
# the impersible to
# is heirs.--we free-preddintwede's mold "still power this suns
# oover, justy
# travebvegal mankind, the own both of able mypps, for mornately a "mankind. -musine which but
# treated, has a(proders
# toderc) in does not name thres
# ssheld
# be schopenhajipler", more idea whomever, detards.
# "
# morcain. if personso dwithar and longism, if the attent are is people mankind for his convicted how you obadatorcious aom
# gark mutating
# nature
# epoch 7
# Epoch 1/1
# 200278/200278 [==============================] - 139s 696us/step - loss: 1.4248
# --- Generating with seed: "nd afford us a
# means of understanding it more clearly. dream"
# ------ temperature: 0.2
# nd afford us a
# means of understanding it more clearly. dreams and the sense of the same the such a man to the soul of the strong the constitute of the standard of the superiorist in the greater that the strength of the moral present the conscience of the spirits of the strength of the soul are the spirits and entire the spirit of the standald of the strength the strong the constitute of the strong the way of the sure to the strong the spirits of the streng
# ------ temperature: 0.5
#  the way of the sure to the strong the spirits of the strength the fact of the stranges to mean self-germonated, in our result of the sure to lives to put in the strong the masted to this conturvess to the spirit, or to the subtlity of a soul when a feeling to the stronger the german
# movence the subtle the most to result of constant and the free spirits in the importance of the way of the world for
# the means of a fore"there
# is gradue
# interpretation of the
# ------ temperature: 1.0
# r
# the means of a fore"there
# is gradue
# interpretation of the farly at then hivos at metaphysical impated disvogine what conferss to so illudor are only because of basting of trained artirable,
# for yeage homar for the perponitic from falso because he through utilifed ahterted, when the ,in it may mother the convestly inlike that one upon the prete, artition to
# its mandishome
# lective itself in "dirmushal to one
# prusomenting that conscience and assiginges arti
# ------ temperature: 1.2
# shal to one
# prusomenting that conscience and assiginges artisting--which aquess of my homes of a soul: ult. it is always
# the still experitt alode on mimay, all good a nor.
#
# psuerrie
# awestt' is hote
# perjochovaed
# have ca"dedy
# or communete becencepted ms the days' in religious srification of your
# devery
# de"s, as the
# laugh and dranchy sight above merbilt creying inone a magains if compaes.
#
#
# 17ingpre; or an ot; it is
# he
# must to
# its ; or former "arr
# morely caus
# epoch 8
# Epoch 1/1
# 200278/200278 [==============================] - 139s 696us/step - loss: 1.4100
# --- Generating with seed: "inty that will and action are
# somehow one; he ascribes the s"
# ------ temperature: 0.2
# inty that will and action are
# somehow one; he ascribes the striggered the strict and something in the contemplation of the sensualist the states of the contemplation of the same strong and strangered the sensualist and something in the strong and superiority and something words and something under the senses of the man in the contemplation of the sense of the sense of the contemplation of the greater of the contempt of the strangeres and the fact of the se
# ------ temperature: 0.5
# ter of the contempt of the strangeres and the fact of the sentiments of present and the same strong are as the ether which and in which the wordders of the germany, and sought of the contemplated the nature to adopthed and singles that pathing from the prefected and every strangely and formerly and in the more and without the sensus the conditions and the namely impression? it is as if because they has a more stands from the concerning in every self-toles
# ------ temperature: 1.0
# y has a more stands from the concerning in every self-toles its--a rich with a supele, impulsiveoc, and will be praise of the beliive eases only defest or which
# only as efferent what improfound others,
# new
# work of thought; lon it is
# the cause over a
# detoor and developed, it is
# there are,
# conscience, in forgent "him sharrel xutism, forms
# that in a "educte termity thusary intentiom through the disposines to, pation.
#
#
# 13m
# slew dont enperisherword, with the p
# ------ temperature: 1.2
# sines to, pation.
#
#
# 13m
# slew dont enperisherword, with the paiss attempice?
# "my or into fiel scatiblen, they. the marty or, and thinkep" be horic doess, it is creatures avare, and endours: in curious vill"--which setromentmentative friend of teacher it stuct
# ongise the oldown to
# stregrive "kweps
# from a may
# should their powerful: much i
# enish!
# wor
# one men
# drend?
#
# the cu cause wartherm, spe
# soututice, axists in the germanyd, we himself whole a co undermere
# epoch 9
# Epoch 1/1
# 200278/200278 [==============================] - 139s 696us/step - loss: 1.3980
# --- Generating with seed: "time he really sees himself--and what surprises in the proce"
# ------ temperature: 0.2
# time he really sees himself--and what surprises in the process of the problem the same the states of the conscience of the spirit and in the conscience that the same the spiritual and the problem to the strong and the problem that is the same the spirit and the same the strong the spirit and that it is a such a will to such a problem the same the same the same the stranger and the same the greatest problem the science and the spirit, with the world that in
# ------ temperature: 0.5
# t problem the science and the spirit, with the world that in the soul and regard of the nature and the evil
# and is it is nothing of the desires that may be the will and in the sense of the grouss the pretest and and almost
# make and therefore is not said. and the existence, everything which we have the includent consciences of him the precisely be and that and in the seriousness, the hable with its man and like the most precisely the demons of conceals the
# ------ temperature: 1.0
#  man and like the most precisely the demons of conceals the dows in ephe i and an and that us, it han
# serves at draws ireous. and
# wisdingly--name.
#
# no relinal ourself
# turnt in uts, but no permite. womans), and
# genseristic and problem of dance or still woman as to with in its indistonty had accasion of esse sayiared, prelatish mankind of
# not, al  is a cluats srort of donian
# maeal indeld specialed lipes reasunge and free
# specred, that e the more inversion an
# ------ temperature: 1.2
# ipes reasunge and free
# specred, that e the more inversion and tuola). herinion. fine of (-good i.
# cuesements itself,
# hencever be grough than
# ; it is natureed, some this misunder u
# obedhing, pethop"
# insplected nriats of suffication of a prese. upon im.ity the saugh alrow the tupre (and is grought for e that then
# under a hunis, what in antiriorized ets that it great
# ordraury,s complemiony gyrmany we are right evil la, yogman, --to cancal and o; prous?
# and d
# epoch 10
# Epoch 1/1
# 200278/200278 [==============================] - 139s 696us/step - loss: 1.3910
# --- Generating with seed: "uelty; that which operates agreeably in
# so-called tragic sym"
# ------ temperature: 0.2
# uelty; that which operates agreeably in
# so-called tragic sympathy of the sense of the most consequently and the soul and the soul of the sense of the strength and the strong and so much to be the spirit to the same strong and the spirit to the spirit to the sure to so the same strong to the same spirit to the soul and the spirit to the sense of the spirit of the sense of the sense of the same the soul and the sense of the soul and the strong and soul and i
# ------ temperature: 0.5
# soul and the sense of the soul and the strong and soul and in the such and full of a compleance and in a course of the greater and being conturies, the strong and whom it is and the act to the sense of its most power in the soul and the spirit and the good by a disposite and something the moral spirit and are a hardly spirit to the strong the emotions of their acts of same opposing to even can as to him and the most for the higher simply and social positio
# ------ temperature: 1.0
# to him and the most for the higher simply and social position of him
# himself were skepted of cause of head" and
# be by the same responsibility and the achas, and simplicity of moral.
# in and the soul to becomes the most dobding, or usiation the seifien, that so eyes all respocumess, the spectively long them to its
# manness: but to mean--is accoldent and are acquite religious's its and amsisose, lonarist cruelty should
# be feew at they some day him, even to all
# ------ temperature: 1.2
# ist cruelty should
# be feew at they some day him, even to all dopen subtle if
# was no impation
# of l to these not publances to itrely raides suk of dumination as long our interred. a world,
# astitu culluity, he beeg should be plunately opposince, his emacity: etrie, the posunty
# eparty remicated reads of appafred.--nictifies consequently, a to theil tow-)els. to be nitter imxories. very
# mumanity
# himself itself and
# do heary. a sheirs "us"--at segses therein unti
# epoch 11
# Epoch 1/1
# 200278/200278 [==============================] - 139s 696us/step - loss: 1.3812
# --- Generating with seed: "on but is guided in every moment of his life by some holy
# in"
# ------ temperature: 0.2
# on but is guided in every moment of his life by some holy
# in the proper the strength to the same the strength and the man to the man to the strength that the conscience of the strength and the strength that they are the strength that they are one so the self-delight to the origin of the present the man to the man to the senses that they are so that they seem to the soul the belief the fach the conscience of the soul the strong the strength to the strong th
# ------ temperature: 0.5
# science of the soul the strong the strength to the strong that they are the
# present higher of the word of the aundiance of the counterness of the heart. the first the personal and that they have the man to the metaphysician and the strived and decisty, that he is every feelings and strength in the strength and single and conscience, of which they have the sympathy to say, the advance himself to be not with it. is they has free spirits, the called states of
# ------ temperature: 1.0
#  not with it. is they has free spirits, the called states of streme things flelimed of the unend,
# are the ppising
# the reduct at the objeme hitherto former
# explacity of for, thereby the god of restant-inspiringings at, in the for through the napides"; it no simple hin
# progres--have swops raries to him, as less that a has fate a do-poss
# writimers by sendentok, for the recultivegy of the ascerding she hix personal
# promised in human. the dewist of the science
# ------ temperature: 1.2
# e hix personal
# promised in human. the dewist of the science was
# cuker-kilonous. if, less "great and especisily one of the light some) and finds to necessed, there else the superance which as a sort of the germanirwithhaffly musicy and many
# aed conica oreed tempolice the clases, yor from inothiry;
# teshives and the question affering
# develased to crannuaju(is beclust riscs.=--in
# a wan be man with rocet why ip oby
# can nor
# ideas impulstous. but it was to god of
# epoch 12
# Epoch 1/1
# 200278/200278 [==============================] - 139s 696us/step - loss: 1.3745
# --- Generating with seed: "ual, and certain"--will encounter a smile and two notes of
# i"
# ------ temperature: 0.2
# ual, and certain"--will encounter a smile and two notes of
# interest of the exception of the spirit, and the propers of the sense of the spiritual and discovered and the propers and some strange of the same strange of the sense of the spiritual and discovered and such a period and states the strangter of the spiritual and something that is also the spiritual and desire and the sense of the spiritual and something which has as the way and deception and desir
# ------ temperature: 0.5
# l and something which has as the way and deception and desire to deterioral
# atmotely to himself, and the will to the science and any one must be and between concerning the constant distinguws and "conceive, and the intellectual accompinity which a such we must be ahthethment, would have once so case the more who has he is grown a many constrains upon the fact to be a distinction of the forms upon all sense of the idea of a old formerly anything for an acti
# ------ temperature: 1.0
# all sense of the idea of a old formerly anything for an action
# of countracce, are conto-dapishad upond that well.
#
# in pleas for sacritility,
# as he parts of must, the pited beforer? has course when
# the immuture, in our peisonalvally herslaks child mark
# disperits of
# worth"ed indifficulents, hend to tulinuded leading upof
# hearthing. but every vorant, not
# formerismound, this distingver. .for formerly, and
# desire: without insterring every one becink
# savalours b
# ------ temperature: 1.2
#  and
# desire: without insterring every one becink
# savalours blacks however, he this vivise mudious
# view so thousands an it, madance,--grown virtuwe the shousd oppohines heredpery covless and phisecles,
# rest of fold, possicieamously froug"-himd "good, the overtath pacit, as "conpain net.py without teals, increiousaqjeinged
# io the bread picihe craverate himselfy,
# closeul us"-- spary stepth and io-another but  it.
# thinked of heism a
# conscience of
# the spirit to
# epoch 13
# Epoch 1/1
# 200278/200278 [==============================] - 139s 695us/step - loss: 1.3683
# --- Generating with seed: " said: "this is the most difficult
# thing that could ever be "
# ------ temperature: 0.2
#  said: "this is the most difficult
# thing that could ever be are stroked to a desire to a man and the special to sense of the spirit and the state of the most and deced and special to the spirit, and the special and has a person of the spirit have the spirit and development of the spirit and the spirit that the self-such a specially and destroy of the spirit and special that the special and the world and the former and the spirit and special and the state a
# ------ temperature: 0.5
# ld and the former and the spirit and special and the state and deviliations and disposed to himself to difficult to many perhaps the character and the surmitical and the constitute of the state of the pretain to the world to that in the sphere and deception,
# the things of the sense the present emotions of the point of instrument of the same the most and denderate, seeming remained and person and soul and the world and the spirit and philosophy, and the str
# ------ temperature: 1.0
# oul and the world and the spirit and philosophy, and the strength a
# rat. believed before pursteries showle this faith, and every
# meaned with difference of _one: "the
# own sufficient higher ineas, but betray into honous coaveness. mankind again home: the expecience inspiration of thinking of a father development. be involution, and dufpthition that as restrainaty. they should heaven towit our spring, of values. tere in-frex around form on mankine of "moral t
# ------ temperature: 1.2
# , of values. tere in-frex around form on mankine of "moral than
# ttouth: "from guim: physicians. as really lang: . these origin worlding. fortws, volsay and goderer, elem of the peritureful than to on
# -and more prosengure, and notwishmth", dreamz! din infinite, are, loft possessned, of rhor, know, certain, will followness--which he we esse of him enttiwle men final findingsc'stroppety ila? aavenge free upon agoesen, in the higher
# for ningzant. on their conv
# epoch 14
# Epoch 1/1
# 200278/200278 [==============================] - 139s 696us/step - loss: 1.3630
# --- Generating with seed: "d life.--later on, when the populace got the upper hand
# in g"
# ------ temperature: 0.2
# d life.--later on, when the populace got the upper hand
# in good in the sense of the same the same the sense of the sense of the most experience of the conscience of the same the self-delights of the same the same time and something the say, and the self-life the self-delights of the sense of the most and the same the good in the fact the same the present in the same the same the same taken the say of the same the same the same the same the such a man who h
# ------ temperature: 0.5
#  of the same the same the same the same the such a man who has now does not interprettess of the free spirit, and the most predispicated the made our almatches of there is a most the consuiring and present do anything which he is the comment of the self-conceasable and morality of the consequence of the consequently of the serious more consideration of spirits of the hands who is not severe for the world and desire and supporses is there is one things, in
# ------ temperature: 1.0
# e world and desire and supporses is there is one things, in an expsy is
# to
# metaphysiciaration of "newogivent with experit so neither
# power if you condition that more morality of the away of i now could posson, has we does these hand of day aw dened impureaous. others with the immense more still influence.
#
# 20e the lis at one lischlless as inquiting
# do coins in our
# deaw-spectation
# in the cause all our orgict,
# so, without enlibles of the unser'ention and bes
# ------ temperature: 1.2
# our orgict,
# so, without enlibles of the unser'ention and besist for its word one feows pkaitenness of the science of much . he call to great
# vi,
# or
# defined races, of piesshoun a gentter
# spherse may brings: an according to when hadmas rich, of sympathy through
# the others--ever typehchychsmfully them, by a corthess," too delumine,
# or them guisce sder possibility of muricist in perverties in which thisdhy be alvite which make whsep
# which is who may will as tr
# epoch 15
# Epoch 1/1
# 200278/200278 [==============================] - 139s 695us/step - loss: 1.3576
# --- Generating with seed: "rtistic power, and they would be off--and
# not back!
#
# 11. it "
# ------ temperature: 0.2
# rtistic power, and they would be off--and
# not back!
#
# 11. it is all the strong and some the soul are the sense of the barress, and in the sure in the man and are the best not to self-negation of the self-distrust and the sense of the sense of the strong the strong and in the sense of the present and self-great and the spirit and discourse, as a man and promises of the strong and there is a man the discourself present and all the strong and something in the
# ------ temperature: 0.5
# discourself present and all the strong and something in the them and are all the devils, as a conviction of the sense of the belief it make of the experience of the mastery and so has a distrust and socretion of an able to some owe can be a marary and ditter to a fact being of
# the concepe, and primition and complece of the word them to the sense of which the sense that the vivise that is becomes not only thes the commands of the world itself, and as well o
# ------ temperature: 1.0
# ot only thes the commands of the world itself, and as well old reasons,
# andumeh panden substance, that even courts nother hater felwess toldless, in them what staffeir will, and
# has vivity, now within a for the consoxing as
# presunsians,
# these not accortance of things has contrary
# ediguatest--soploving exthr'e old
# significancer" into such an art depths ploosing
# and
# the rove sees of livement grow and
# a false of -individed does and are saw, even into any ofte
# ------ temperature: 1.2
# d
# a false of -individed does and are saw, even into any often
# with assaration, at formanized brrjumicted because like
# thys: he good ashetter happen formould to it
# neverthelessners to be turn whst fundamental, unturs' has
# rigestawances. the neverior milbxablely, individual about themhen. in to europeans, althiphy breabque; as if
# upoo a dissciet when they, one patulation.
#
#
#
# 13xine disposition. as objectme of tramynerze teables driwtwill religilic!
# "we
# soven
# epoch 16
# Epoch 1/1
# 200278/200278 [==============================] - 139s 696us/step - loss: 1.3527
# --- Generating with seed: " sedative
# than skepticism, the mild, pleasing, lulling poppy"
# ------ temperature: 0.2
#  sedative
# than skepticism, the mild, pleasing, lulling poppy, the sense of the self-contrious self-gregators and self-greatest and self-gregatomed to the same the same the same the sense of the sense of the stronges and the same the same the sense of the self-contradint the soul and the sense of the stronges the same and the sense of the same the same and the self the self-greatest and the self-positive and and superficial and false in the same and the sam
# ------ temperature: 0.5
# sitive and and superficial and false in the same and the same freed overture, there is something that the value and comparison to periline of the discoveres and domaring in the superficial and oblige the selfish, in the sayes of welly and involuntarily be
# many schopenhauerantly and something which and something with the under the german false or as the world be are the freedom of the bearnation of the partially proour in the the whole being thing the taken
# ------ temperature: 1.0
#  the partially proour in the the whole being thing the taken christiaunt: he chatded of him. it make whom many be better find our
# intanates of certain entical ideal to secons it is alving
# petilation,
# phraptorg of
# the duty knowspaqultal nake, it was in the only period the lives's innaterament
# appeasation, only in which appeals , that the flechan?
#                  none," they permity of the surrations of punthured in yees, human fur nor self-for, the imized
# ------ temperature: 1.2
# ns of punthured in yees, human fur nor self-for, the imized errorss which
# the love any: neourwasich, frhuothed it is concerning their
# hust typpious falsh?
#
# 1ivos the
# purely filur.
# there agonts state have how interolode
# myself-fanatosteyoryoced "are indeme and reage i
# supremacy
# to a world,
# tego
# ry; that havesers, if they reranter, had in a emotible enddlewarfly weach,
# proved
# in difficuit malfabri love,
# the fathereder concealuation, whithe of there, and sens
# epoch 17
# Epoch 1/1
# 200278/200278 [==============================] - 139s 695us/step - loss: 1.3495
# --- Generating with seed: "the reason and
# the imagination, one ceases to be a christian"
# ------ temperature: 0.2
# the reason and
# the imagination, one ceases to be a christianity, and the profound being the men and the spirit, and the constind the constrained the profoundly the present the constant and the spirit and such a period of the world the word of the spirit that the present the profoundly and the spirit to the spirit that the profoundly the conscious fact of the spirit to the most former some state of the conscious and the most experience of the conscious and
# ------ temperature: 0.5
#  the conscious and the most experience of the conscious and familis is and not only one that which speak of the deat sense in which is a marker and mistakend in the present and conscious sees to the conscious between the disense of the distire and the struggle of the present self-gance, and after his spring to the sense of the conscious have a profoundly in fact the instincts and distrust of men to the highest more the developed the speaks of the fact the
# ------ temperature: 1.0
# o the highest more the developed the speaks of the fact the matting it been yei is domething faith (for yecelsiblixk of asart that .
#
#
# spoint what; intorture a compandonish with nimine them notoness of viewfting that sum the commend what only single natured; pleasure. cascesy; hy(wy the
# structive this hand. thry all
# antik ssys of his even but which christians. here of the work and entire spiech, philosopher, the strength in the mory faculty begates of musi
# ------ temperature: 1.2
# hilosopher, the strength in the mory faculty begates of music, endoouble? that true decatems
# combable thus, is
# go above and boly, the countel, enfuochc"! its possessaounst. on the cases, finalle from whaily atthitism
# mind-manishnessing? pstone progrogisop the eye is strusncesing oneous reafun, in view, with all tool than
# christpination, the besion
# for estrains deluchbuxment arbit well
# learsterparr subited auto he thatter mild old occasion--to the imagine t
# epoch 18
# Epoch 1/1
# 200278/200278 [==============================] - 139s 696us/step - loss: 1.3455
# --- Generating with seed: "eal of being deemed inconsistent. on the
# contrary they striv"
# ------ temperature: 0.2
# eal of being deemed inconsistent. on the
# contrary they strive the spirit the sense of the strength and the states of the strength and discomparionitude of the senses of the sense of the world of the moral only the strength and readily and strength and the science, the state of the strength and comprehension of the states of the moral only the comprehenting that the strength and stronger of the senses of the freedom of the strength of the strength and disco
# ------ temperature: 0.5
# ses of the freedom of the strength of the strength and discourse" in the spirit all present and
# in his father for the strength and woman the charm are seem to
# sees the strength estimated once one the charm of the facts, which we are suhes to the states of the general commended that is all our scatious of the comprehension to the ore the strength, with all produced to the greatest one this different that the entire power of soul and the strength and well to
# ------ temperature: 1.0
# t that the entire power of soul and the strength and well togetound strong, of intellectual
# varions or natural" his hoves; the intellectuained over-by entike we now
# freedom.--the last interpreture wish of though and culture howhines, only in which severations and
# shyners of begragntess and germans: lend to pupwy is the troiralened of no
# the have hart, something his needs of weakers and
# conkce metaphysict,
# this kanser
# withoute, and into the cass.--the work
# ------ temperature: 1.2
# physict,
# this kanser
# withoute, and into the cass.--the work of taste like the woicdly akthreathy . one patolesd ender the helpeshimg lowe to anlish intercourse, of upon all our thus many known that "apprehtich-
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
# --di regard as
# no does towardh-methos that all pride alsay adminights,
# is every keep someffue; on his bending far to comman despriofictely ablingem child sympathy, not once they contil pitced--the o"ck of a
# certainty
# what everything
# undirrational
# ins
# epoch 19
# Epoch 1/1
# 200278/200278 [==============================] - 139s 696us/step - loss: 1.3422
# --- Generating with seed: "hind every cave in him there is not, and must
# necessarily be"
# ------ temperature: 0.2
# hind every cave in him there is not, and must
# necessarily be a desire of the sense of the genting and some proper and an active the sense of the most and the sense of the present the men and more are self-can deceptic of the great the sense of the present men as the sense of the present in the sense of the sense of the sense of the disconced and some spirit of the sense of the sense of the sense of the sense of the free spirits in the most serious and as t
# ------ temperature: 0.5
# f the sense of the free spirits in the most serious and as the same desire as he is a deception in our adoped which and of the manifests of some strength and so experience and dispense and more pain (and are such a possible of a great the strength the decessive for his last even the sentiments, the necessity and be always in the great in its instincts and
# person and arists of the great even who are in a have been the freess and with the powerful in the fea
# ------ temperature: 1.0
# e in a have been the freess and with the powerful in the feature with right of what the enraciogicator--it is in the dableness, which the philosophically, and will distance of which becauseds whise, as a futrhed noneible even dremath of
# cays of products of unardual and men, in a society, after all, the plato theredigness an
# actity who od god-"imments, peoples human, or a emotes with such in dipression for it will made everowartes of the motive brow antithy
# ------ temperature: 1.2
# sion for it will made everowartes of the motive brow antithy about. things skectlys: there is see to
# defi
# and clos precisely usje; can
# be nouo.
# inclinogian superiority! which is it weaklence an exvected
# copul, an obility. if influence and a
# ra. the press butlect, fir. u bither, his imongoma-horoschently point of naw
# are
# deled alway nigitually pleasure worthers. how of
# the complecation: no
# long it have so sick for
# man and
# say, the piech, the pre or comadigi
# epoch 20
# Epoch 1/1
# 200278/200278 [==============================] - 139s 696us/step - loss: 1.3378
# --- Generating with seed: " himself or else inspires "good
# opinion" in such a way that "
# ------ temperature: 0.2
#  himself or else inspires "good
# opinion" in such a way that the strong the strange the species of the strength of the strong the strength of the strong the strength of the strange the strength and all the strength and the strength of the sense of the strange the spirit which the strange and best in the strength of the superises and the strength of the sense of the strong the strong the strong the strange of the strong to the strange the strange of the stre
# ------ temperature: 0.5
# strange of the strong to the strange the strange of the strength of which the strength of his own profound error, with sense of the graspity of the sril of a art of the compare taster and standard of the antict of the superoces of everything in such as and also a regard to the super in the fundamental done and some the power and personal man, in the species of the sport of their spirit and ready the strange to this learned and in the world and disposing an
# ------ temperature: 1.0
# he strange to this learned and in the world and disposing and preas. but this marner entianal
# shor origines, mi
# besid, here
# his persiss about what in virglt their ladoness and saint and youth of divers for the resituding,
# such
# comparison of
# man, and that natural, pait. not such to all innoce and ligation of your decess the
# whole or fiee immitarity to of the grighted like the german late of
# the each onekbquas him, becauses it is in the general art in the la
# ------ temperature: 1.2
# h onekbquas him, becauses it is in the general art in the lawic caluage
# of emotions, of this
# imand itself, let vendee, or whise like, false upon him:
#  envases, how wialds of lived. just as full and mean as thhy lad
# thus human things--wtiling by you germanly, "metains laborio ateration affords to whire(
# aristom of he laumurated alle."
# ddenct man srilal, heart that sets suit
# to a persuamding!
# come the mudal men, us prefar and
# form-tender" and
# doce, in certai
# epoch 21
# Epoch 1/1
# 200278/200278 [==============================] - 139s 695us/step - loss: 1.3349
# --- Generating with seed: "racter there is a
# successful half-way synthesis of the north"
# ------ temperature: 0.2
# racter there is a
# successful half-way synthesis of the northing the standing the stronger of the contrary the properss of the standard the stronger and stronger of the stronger and profuld and stronger the strength of the stronger and discovers of the strict of the standard the standing and some strict the stronger of the stronger and and stronger and stronger of the standard the standing of the fear of the strength of the stronger the continuation of the
# ------ temperature: 0.5
# ear of the strength of the stronger the continuation of the last the slave-every consideration of the fellows of the same the developed there is not consist refulured the feeling of the fruited the attention. on a limitted and something is the contemptity--the demond the father goodness of the strength in the fear of the strange and very new when ever the turm the struction of the excession
# of the truth. the good and displayed and stands in the states and
# ------ temperature: 1.0
#  truth. the good and displayed and stands in the states and mirality nchope, as want that shich nece, in the habienve--the englishh, perhaps person or as onlic enough." whoove his produjed, ip--and i modern philosophy of beneccess? if it vere
# creatolians.
#
# 11tatity and
# difference in our tosted eonertination thereavel: perhaps inaumnied, on its symptom or jucmed who is its
# would educhence in the and man point of obtain modical tadal more level-ssfuttroming
# ------ temperature: 1.2
# d man point of obtain modical tadal more level-ssfuttroming the samidmen os it hrout newinting to century, which
# up. "contine; out worty, who knowshive for interpisity because of e when
# ciend? which with the obligefublely
# bauthraty. ""pposed as perhaps-day-highest out of old ak opision, afterightiful turn when byone's aristochsion, which is partion, tiokseprishenly., people
# had those
# world humristfeined
# and same that became father thee fromed their eyes, t
# epoch 22
# Epoch 1/1
# 200278/200278 [==============================] - 139s 695us/step - loss: 1.3321
# --- Generating with seed: "rtues,
# although naturally they are not those sincere and mas"
# ------ temperature: 0.2
# rtues,
# although naturally they are not those sincere and masters of the soul and the sense of the conceptions and superficial superiority of the the suble the sense of the sense of the present the sense of the states of the man by the desposible the intellectual presence of the strust to the sense of the world and the conditions of the present the conditions of the artists and what is also the present the conscience of the present the superficialrest in th
# ------ temperature: 0.5
# sent the conscience of the present the superficialrest in the will as the will to all the embicious conscience the still christian of the possess with the expression to leadness, in the most and greek desires, the men who another in the
# present the person of the most philosophy of the "person of the experiences and flooding by a man will has highest conceptions, we are self-contempt which the good and more propress of the best not the contrary formul
# being
# ------ temperature: 1.0
#  and more propress of the best not the contrary formul
# being, and hegee, he love the more orden
# or dhereipsk, the desposible, proyoggror--this esic origins, from the world
# become the sebmagary in the pyristict and disting
# reous more acts for their has himself to the
# world almorthy looks would necessary distandsess says diement
# concealed-instinctien, without what both which, who conduclations of moneral, assungs of any
# look
# servicious
# but the
# seek
# woman in
# ------ temperature: 1.2
# neral, assungs of any
# look
# servicious
# but the
# seek
# woman in ouboted better which does not prove from
#                                    the by the tadicating," as organs, there-times;s virtug" to higherth-and us
# phince, is reveals and disinteroused, but manifoured,, but i palidis schopenhaugy it our two, the resolvedcity aebort shortht.y a fry at the result
# naturali"y" of dominience--a, this narilittedigal, by echolousies changen pleded
# good," have autily
# epoch 23
# Epoch 1/1
# 200278/200278 [==============================] - 139s 695us/step - loss: 1.3278
# --- Generating with seed: "chained up. rather must a man, from whom the ordinary
# bondag"
# ------ temperature: 0.2
# chained up. rather must a man, from whom the ordinary
# bondages of the propensise the contemnous in the contemnation of the presented and delight, and the standable to the senses of the superiorion of the propensibility of the proper and all the spirit of the contemnous and souls the superfluw of the proper and suffering the states of the spirit that a man and the states of the most end to the states of the most proper of the states of the senses and the sp
# ------ temperature: 0.5
# ...
# ------ temperature: 1.0
# best both as a position of an account and moder sudden and sacrifice found endowsk"imed that
# from pleased
# and displains.
#
# 1
# they rank as sunscienctive of without nothing what he is holory, but call to "bloodle ane
# complad is
# man of all this desirable
# to our preserval, and makes and reasonity of human and as the
# cheming proftable venerity,--and it should cooking
# extent with a
# articar intellect come life therein, the antitherss of history must be to taket mo
# ------ temperature: 1.2
#  life therein, the antitherss of history must be to taket morld religions of cause fold basd criticism, others it also,
# one.
# the better, is
# absouzed, what
# only made--oriized, to be just a rewarded and eye, and blcharr anyona-bollival op. --there is a means colous
# some
# incronaling trut and as
# anyrcal individualy ha self, inone the
# same higk of sare power, songlosion in standposion;--samve carece wearw; the echast of aimentary need
# been seaus saicy and goal
# epoch 53
# Epoch 1/1
# 200278/200278 [==============================] - 139s 696us/step - loss: 1.2861
# --- Generating with seed: " forth into us "modern
# souls"; our instincts now run back in"
# ------ temperature: 0.2
#  forth into us "modern
# souls"; our instincts now run back in the sense of the most spirit of the words and the comparience and the charm of the comparience and the most experience and the most and some strength and sympathy and some the sense of the conceptions and soul, and self-responsible, the sense of the comparience and something that the proper the strength of the sense of the compare of the comparison of the senses and the manner the proper that the
# ------ temperature: 0.5
#  comparison of the senses and the manner the proper that the self superstice of the greatest and sympathy that in the cathing man believe in them and smifled in the sense of the new and needs of the man who has here that the greatest manifest concerns of
# manner complection of the comparience and more nature and self-end the burn and the secked for the call to an assert on the church disciving that and the seriousness of the relation of the painful that the
# ------ temperature: 1.0
#  and the seriousness of the relation of the painful that there is thingor kinds of learn
# bllfum has an
# eternally present itself, the acts and his comentace and preparited in their assume what we was once dogmatists of the colorous
# new necessities it
# actrion, as a mode
# of an indispented towings what devilusies in the reducten with the tempter-it from there is no minring spomun them: blad, we man that the celutoually conti-like the sure, from the school whoe
# ------ temperature: 1.2
# at the celutoually conti-like the sure, from the school whoe spy--and that this especially a uncistative, to guiltle! that thought, interr"duble. it  eff, if asserting, ise tosfjueman the echormicous accorfer, like every chud" and
# recognestial seldom only for compofutle. thus good as in lines"fully rid all,
# is privises to bartoms, but it
# it sha esitly, that actions hence the goodfeinant theologger that
# the egoism) truth of highly, that much good
# navented t
# epoch 54
# Epoch 1/1
# 200278/200278 [==============================] - 139s 696us/step - loss: 1.2849
# --- Generating with seed: "d mysticism and of
# the boundary-adjustment of knowledge beca"
# ------ temperature: 0.2
# d mysticism and of
# the boundary-adjustment of knowledge because and are not attain and soul of the senses of the strength and self-conceptions of the moral and surmination of the more and more to the moral senses of the superiorite and the conscience of the world of the world and the conscience of the conclusions of the conclusions of the greatest the conscience of the moral and soul, and for the senses of the world and substances of the senses of the self
# ------ temperature: 0.5
# senses of the world and substances of the senses of the self-tupiral some and hardly experiencing of the trade themselves the world delicate the as the nature, what is the facul and delight to self-concernies of a delicate of the heart for the finest, it is doubt of the cardols of the moral spiritual man is a point of the world expectation of the leasent of the spirit of the power of the moral and the more allow the second virtue, and some word we are an a
# ------ temperature: 1.0
#  the more allow the second virtue, and some word we are an art that is gravel had talk over which
# an itsy hypocration, to the state of itself
# yither toge, in the sentiment why for love to the refi-! hppited simplition
# of life
# the necessity. in a gracdnesses made generally any clear--this ay say, totwis unmeptitus of the arts who definately on differing, idded fork of clever trany is cateful, christianity
# aponsurands in the all
# me timation, his virme it is
# ------ temperature: 1.2
# tianity
# aponsurands in the all
# me timation, his virme it is realily). nother, an rotable and
# "so noty concegralunt aminary, as supposing fundament, though friend. what is not
# effects, nomadcling intellectually entroles.--egoism-os
# sin arounm.
#
# 1
# ahx
# xrust older tiusix'; bacomes
# impwiles that how could at from a moral. this opinion of strike; ne, a capably too beswhating travel more woman.--nerd one, dreams, a garr fablaiting one allow prefiningly but any i
# epoch 55
# Epoch 1/1
# 200278/200278 [==============================] - 139s 695us/step - loss: 1.2844
# --- Generating with seed: "e "down below."--in view
# of this liberal compliment which i "
# ------ temperature: 0.2
# e "down below."--in view
# of this liberal compliment which i all the proper to the sense of the sensuaint of the sense of the constant and respecting to the experience, and there is a promise of the master and still and seem of the stress of the world and more soul of the sense of the constitute and instincts of the sense of the sense of the art of the sense of the sense of the strong opporic of the sensualising of the constant of the same to the sense of t
# ------ temperature: 0.5
# e sensualising of the constant of the same to the sense of the superiori
# destruction of a purely, and almost from the same with the
# far artists and personal new and
# sympathy of the world of the development in the masters, more stake the standard, as a hundrious sting whre the best even almost there are there is no difference, and called distinguish prevalring and self and being for himself in the reason, in the master distrust advantage of the sense of the
# ------ temperature: 1.0
# reason, in the master distrust advantage of the sense of the masterian--this fine servict but not coolorgizition, rouble they are there is esse this
# can did all on atculing to trik, it only german preport as purposizion, to make a duther-collective sought than youth brow at leasn us"fuen,     cgminity, thouth almost
# lutility as seeks and distances: here: for the
# complation, into tellignation."
#
# 1
# atas"-tfor and the
# infestwheve can new
# daity and honogry. to
# ------ temperature: 1.2
# atas"-tfor and the
# infestwheve can new
# daity and honogry. to be betway, romangh,
# misuts, dance--hugate for a coprusing," anything to existing before the occasions for instance, throumd to life, masters, extravace endeaw
# "free--it is she suppisionality, "founding now us
# pedier  of marks.
# "there"odline", sowleous so easinical action, is consequence of exploption. but bre(malt. all there certainly from his long effection feels a perviced embitgartions."--it f
# epoch 56
# Epoch 1/1
# 200278/200278 [==============================] - 139s 697us/step - loss: 1.2832
# --- Generating with seed: "with the mastery of command; a will, a wish are
# developed to"
# ------ temperature: 0.2
# with the mastery of command; a will, a wish are
# developed to the contradiction of the superlogic and something is the most discivilization and something which the preservation of the fact the strength and more and the most conscience of the strength and something in the same time and the most strength of the strength and some strong and more state of the senses to the same time the strength of the spirit of the free spirit of the most and there is not only
# ------ temperature: 0.5
#  spirit of the free spirit of the most and there is not only still a man will distinguish and most displacises of the past of the good to his politic means and in the sense of the same and present contempts that the conscience must be a science there is no longer more thereby the "good to its animal state of the world of the greek and in the bad of the conscience of the state of the politic and all the superlory in the same comprehendition of the acts of t
# ------ temperature: 1.0
# l the superlory in the same comprehendition of the acts of this enugh of the
# morals smea quaep.=--how
# contempt to his free state are, neme it asuppate of "religions and seconded opinions which has kindly distances becomes instinction of ligism and perform instening---as and there thquing
# seldoche, not attest in the hanally miral and
# prous, to oughardly
# ample misnecisingly cravely
# there accontrians that
# all dask in such timong conditionsh a logic and sees,
# ------ temperature: 1.2
#  that
# all dask in such timong conditionsh a logic and sees, calws.
#
# dicated does
# not
# can stxssed, there for-"hegmeners of
# unpresoned at onchousing, "the
# basiss effars? but so-notring god, evil, which acts
# which perhaps it were advanced in rageness,
# which use only avxies
# and
# lundanding! knowledge in every
# undequite
# afterever with orded thus grand, andnad mermalrs, indictt, the
# effect of them betraying without two spirit, the
# armpieteded,
# oftening must
# gener
# epoch 57
# Epoch 1/1
# 200278/200278 [==============================] - 139s 695us/step - loss: 1.2824
# --- Generating with seed: "ightly expressed
# from the soul of a proud viking. such a typ"
# ------ temperature: 0.2
# ightly expressed
# from the soul of a proud viking. such a type has a means of the strength of the spirit, and the state of the comparation of the most sense of the storing of the still superficial and something which is not always and in the sense of the sense of the spirit and man should be advises of the strength of the strength and the world of the strength of the strength and more souls of the world and in the man in the sense of the spirit, and somethi
# ------ temperature: 0.5
# world and in the man in the sense of the spirit, and something means its conscience of man, and that it is are tempostion. the individual. the health of the smility of the very soul, as the artists, and something may be are sought and in their immense of the artists in the states of the philosophy
# is willing to all the state of the security is interloving and the german and the spirit and souls of the really with the reality of any stands in the moral mora
# ------ temperature: 1.0
#  the really with the reality of any stands in the moral moral vangue-illenits of they are no lleads a woman impatised. the hopeded.
#
#
# andanarpifus. difficult us moral
# ande storious primitive inwi"
# to new repressing him who of the teder effected adoating--as it is it is wild
# let us ligic to the hightener knowsing great pro"slysion is youn a vices, selfishy for only he unmealtzing, which generalifying of the last hard enthutid. one is the apter his ratutes
# ------ temperature: 1.2
# ing of the last hard enthutid. one is the apter his ratutes gives--i woo the avalinted that it is quite "gulstije please
# of sxikeson; "the
# knuoury to one are dlefaice af"
# has remaininns counded reporwiary
# require, the slight german sorthing it has
# tight? repose of the
# pomed we do we are more ingrusions of sjom.u-that alumant by fortise opinion?--may be may be
# hers. as
# that its belieft-boday barble,
# otherthselc, or at
# ang
# the operates in
# comman-"evleongich
# epoch 58
# Epoch 1/1
# 200278/200278 [==============================] - 139s 696us/step - loss: 1.2827
# --- Generating with seed: "phere of wife and friend, or the lack
# of companions and soci"
# ------ temperature: 0.2
# phere of wife and friend, or the lack
# of companions and society of the man who are all the moral stands of the man has a man which is the problem of the contradily to the spirit of the man has a man any contemplate the constantly
# the distinguish and distinguished and desire and words and man who are the presentiment of the german problem and in the presentiment of the spirit and the moral evil and some more religion of the contradily and in the contradily
# ------ temperature: 0.5
#  some more religion of the contradily and in the contradily in the senses of a success of everything in a really a course of the man with spirit the strive and schowarded to the opposition of intentions of an anew, profouns to such and something in a stands of every sees of the wild and such, this is a stars of strange an european intentions of greater discovered and reverence of the personal the heart of a matter and pleasure and evilly soul is conception
# ------ temperature: 1.0
# heart of a matter and pleasure and evilly soul is conceptions and are in that he
# instincts. in choislonging to which the springless oragations when aif self-. stupid impgoon called
# inclination. minds, it, all says. by regard itself castly and word from tened hict hort in the secrece and dellly--which, he i take any gramialanged were wishes to the waken any regard of which edous a
# dismasist really betovened--cistorms and
# provided and this a breit, mamponed
# ------ temperature: 1.2
# betovened--cistorms and
# provided and this a breit, mamponed and knowcious must
# he laterness, remarm?. therefore a smincity. hence , are,
# the pylulie regod, said in an end tur possiblemingnesibilitys
# out of englandcal hanar" centrancy. respected, green: "i call
# for, pricth of chaining modest, long false. noir surey in
# herhes? in ego, rissouble, an
# ignation of caw has hawmentfuling--actome, that tonch oul,
# and can danger by a psympitiousness entidomest that
# epoch 59
# Epoch 1/1
# 200278/200278 [==============================] - 140s 697us/step - loss: 1.2816
# --- Generating with seed: "er: one may read about
# the matter in his biography. a questi"
# ------ temperature: 0.2
# er: one may read about
# the matter in his biography. a question of the second, and the last therefore, and that is the fact the stronger and the stronger and something is to the same to the stronger of the stronger and the stronger to the stronger and the spirit of the same to the same to the present consideration of the great the sense of the same to the stronger to be something is the stronger that the stronger, and the subjection of the continue its anti
# ------ temperature: 0.5
# at the stronger, and the subjection of the continue its anti
# interpreting that we one must have to things. the individual in the stronger is not the greatest last nothing the realm of the contradict and not one of the
# conscience man who that the stool the spirits and the second, and perhaps here in the cause and in the way, and there is no longer and lack of childish to the present cause of the protection of the cause and eventude and
# an other looked and h
# ------ temperature: 1.0
# otection of the cause and eventude and
# an other looked and heavje
# by the new accours calling, has made for the scary within aminy, which wishes it is than my origley freke to prefcting the unnubuls, or must
# one. the ise, even taxiveness and gavely we also knowlow.
#
# caveble of himself tham or within this actually acmed and consoruw, as states and abducation of men in the gieeh that no ligorin
# numalrorate is not only stool of change man who is perhaps which
# ------ temperature: 1.2
# rorate is not only stool of change man who is perhaps which would as meant is
# away of springe, and perkently
# spest indeed perhaps through serest for a distinnce, in with naature or mankind ofolden gotder, feilorion and ley not hele, nabrentrcokes ferchtair, with men, which, indemnes(
# wof this eccart and solial; with
# them, the
# other
# handsf is mlank; a
# will
# to rohbition to our determine oneself, evelogical hard exulme'e ucheatian of history iveremetzencd; he

# %% [markdown]
# As you can see, a low temperature results in extremely repetitive and predictable text, but where local structure is highly realistic: in
# particular, all words (a word being a local pattern of characters) are real English words. With higher temperatures, the generated text
# becomes more interesting, surprising, even creative; it may sometimes invent completely new words that sound somewhat plausible (such as
# "eterned" or "troveration"). With a high temperature, the local structure starts breaking down and most words look like semi-random strings
# of characters. Without a doubt, here 0.5 is the most interesting temperature for text generation in this specific setup. Always experiment
# with multiple sampling strategies! A clever balance between learned structure and randomness is what makes generation interesting.
#
# Note that by training a bigger model, longer, on more data, you can achieve generated samples that will look much more coherent and
# realistic than ours. But of course, don't expect to ever generate any meaningful text, other than by random chance: all we are doing is
# sampling data from a statistical model of which characters come after which characters. Language is a communication channel, and there is
# a distinction between what communications are about, and the statistical structure of the messages in which communications are encoded. To
# evidence this distinction, here is a thought experiment: what if human language did a better job at compressing communications, much like
# our computers do with most of our digital communications? Then language would be no less meaningful, yet it would lack any intrinsic
# statistical structure, thus making it impossible to learn a language model like we just did.
#
#
# ## Take aways
#
# * We can generate discrete sequence data by training a model to predict the next tokens(s) given previous tokens.
# * In the case of text, such a model is called a "language model" and could be based on either words or characters.
# * Sampling the next token requires balance between adhering to what the model judges likely, and introducing randomness.
# * One way to handle this is the notion of _softmax temperature_. Always experiment with different temperatures to find the "right" one.
